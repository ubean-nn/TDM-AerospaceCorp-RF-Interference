# %%
from experiment import Experiment
exp = Experiment()
exp.dB_distribution_study()

print("done")
# Out:
# Global min dB: -135.69371254286867
# Global max dB: 0.0
# done

# %%
# from experiment import Experiment
# exp = Experiment()
# exp.dB_histograms([0])
# exp.dB_histograms([1])
# exp.dB_histograms([2])

# print("done")

# %%
from experiment import Experiment
exp = Experiment()
exp.std_distribution(0)
exp.std_distribution(1)
exp.std_distribution(2)
exp.std_distribution(3)

print("done")

# %%
from experiment import Experiment
exp = Experiment()
exp.std_distribution(4)
exp.std_distribution(5)
exp.std_distribution(6)
exp.std_distribution(7)
exp.std_distribution(8)

print("done")

# %%
from experiment import Experiment
exp = Experiment()
exp.plot_std_dev()
print("done")
# Out:
# 16210/16211
# done

# %%
from experiment import Experiment
exp = Experiment()

exp.plot_mean()
exp.plot_median()
# Out:
# 16210/16211
# 16210/16211

# %%
from experiment import Experiment
exp = Experiment()
exp.give_me_a_specto(0)
exp.give_me_a_specto(1)
exp.give_me_a_specto(2)
exp.give_me_a_specto(3)
exp.give_me_a_specto(4)
# Out:
# Selected spectrogram: 004098
# Label: 0
# Min: -93.58405436521113
# Max: -2.042196235757501
# Median: -37.4560270327876
# Mean: -38.661922197207666
# Std: 7.565530642830918
# Selected spectrogram: 002158
# Label: 1
# Min: -88.07131635410761
# Max: -9.825433613928723
# Median: -32.36706705215224
# Mean: -33.46966302999262
# Std: 7.63212941429858
# Selected spectrogram: 007483
# Label: 2
# Min: -81.82715324940963
# Max: -4.25852946666226
# Median: -25.18991718023502
# Mean: -26.492923305911077
# Std: 7.934029372249638
# Selected spectrogram: 000172
# Label: 3
# Min: -89.55356294620412
# Max: -10.83175199722885
# Median: -34.30010477765623
# Mean: -35.50559059211683
# Std: 8.025710422658848
# Selected spectrogram: 000725
# Label: 4
# Min: -89.5478502070426
# Max: -17.463454812989696
# Median: -36.33525859664408
# Mean: -37.55322488772862
# Std: 8.034386530354672
