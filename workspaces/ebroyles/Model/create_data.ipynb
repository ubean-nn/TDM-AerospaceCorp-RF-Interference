# %%
from data_manager import MyDataset, SpectoFeatures, LABELS

train_ds = MyDataset(
    filepath_txt = MyDataset.TRAIN_TXT, 
    get_features_func = SpectoFeatures.get_features_f1, 
    resize_shape = (128, 64), 
    labels = LABELS
)
filepath = "train_128x64_normz_no_artificial"
train_ds.save_all_items(filepath, norm_type = 1)

test_ds = MyDataset(
    filepath_txt = MyDataset.TEST_TXT, 
    get_features_func = SpectoFeatures.get_features_f1, 
    resize_shape = (128, 64), 
    labels = LABELS
)
filepath = "test_128x64_normz_no_artificial"
test_ds.save_all_items(filepath, norm_type = 1)
# Out:
# 3295/329514
# array([[-1.32799625, -1.27964985, -1.22431278, ...,  0.4940522 ,
#          0.33427191,  8.        ],
#        [-1.48732197, -1.47612715, -1.41338289, ...,  0.86046618,
#          0.91461778,  8.        ],
#        [-0.66333568, -0.70109379, -0.71187085, ...,  1.17453527,
#          1.33668756,  7.        ],
#        ...,
#        [ 0.86515588,  0.85356921,  0.85255295, ..., -0.81456918,
#          0.70358294,  1.        ],
#        [ 1.24383628,  1.26439774,  1.28236854, ...,  1.33156991,
#         -0.19331525,  0.        ],
#        [ 0.19307831,  0.14249241,  0.16167359, ...,  0.86046618,
#         -0.77366114,  2.        ]])

# %%
from data_manager import MyDataset, SpectoFeatures, LABELS

train_ds = MyDataset(
    filepath_txt = MyDataset.TRAIN_TXT, 
    get_features_func = SpectoFeatures.get_features_f1, 
    resize_shape = (128, 64), 
    labels = LABELS
)
filepath = "train_128x64_norm0to1_no_artificial"
train_ds.save_all_items(filepath, norm_type = 2)

test_ds = MyDataset(
    filepath_txt = MyDataset.TEST_TXT, 
    get_features_func = SpectoFeatures.get_features_f1, 
    resize_shape = (128, 64), 
    labels = LABELS
)
filepath = "test_128x64_norm0to1_no_artificial"
test_ds.save_all_items(filepath, norm_type = 2)
# Out:
# 3295/329514
# array([[0.13271208, 0.1434012 , 0.12917349, ..., 0.6507937 , 0.6031746 ,
#         8.        ],
#        [0.09469907, 0.0966006 , 0.08280592, ..., 0.7619048 , 0.7777778 ,
#         8.        ],
#        [0.29129124, 0.28121242, 0.25484475, ..., 0.85714287, 0.9047619 ,
#         7.        ],
#        ...,
#        [0.65596896, 0.65153086, 0.63850415, ..., 0.25396827, 0.71428573,
#         1.        ],
#        [0.746317  , 0.7493896 , 0.7439121 , ..., 0.9047619 , 0.44444445,
#         0.        ],
#        [0.4956202 , 0.48215342, 0.46907285, ..., 0.7619048 , 0.26984128,
#         2.        ]], dtype=float32)
