# %%
import numpy as np

# %%
data = np.load("../fiot_highway2-main/data/000001.npy")
print(data)
print(len(data))
for i in range(len(data)):
    print(len(data[i]))

#rows: 512
#cols: 243
# Out:
# [[-48.2603059  -48.78561461 -60.91323802 ... -46.44137591 -49.07059081
#   -45.7440373 ]
#  [-45.32726865 -48.13739317 -48.4194958  ... -53.95196747 -50.73405319
#   -50.06238434]
#  [-45.92139001 -48.66170341 -55.92641881 ... -52.20443938 -54.45985106
#   -49.12088943]
#  ...
#  [-73.58602564 -45.42479232 -44.92458627 ... -56.74397522 -66.13102752
#   -48.3557265 ]
#  [-59.54719477 -45.91808714 -48.4233111  ... -56.91954523 -49.30532674
#   -45.31640347]
#  [-50.51239195 -44.09025821 -56.11648066 ... -49.84769453 -47.66364564
#   -44.60498235]]
# 512
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# 243
# ...
