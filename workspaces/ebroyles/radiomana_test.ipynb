# %%
# !pip install git+https://github.com/the-aerospace-corporation/radiomana.git
# %env DSET_FIOT_HIGHWAY2=../aerospace-rf/ebroyles
import radiomana
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/the-aerospace-corporation/radiomana.git
#   Cloning https://github.com/the-aerospace-corporation/radiomana.git to /tmp/pip-req-build-2dccoljt
#   Running command git clone --filter=blob:none --quiet https://github.com/the-aerospace-corporation/radiomana.git /tmp/pip-req-build-2dccoljt
#   Resolved https://github.com/the-aerospace-corporation/radiomana.git to commit 73de6b530f392c2fb3d11c3eefbc7a9a4590e803
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.12/site-packages (from radiomana==0.1.0) (2.7.1+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/site-packages (from radiomana==0.1.0) (1.26.4)
# Requirement already satisfied: einops in /home/x-ebroyles/.local/lib/python3.12/site-packages (from radiomana==0.1.0) (0.8.1)
# Requirement already satisfied: lightning in /usr/local/lib/python3.12/site-packages (from radiomana==0.1.0) (2.5.5)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/site-packages (from radiomana==0.1.0) (1.8.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/site-packages (from radiomana==0.1.0) (1.7.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/site-packages (from radiomana==0.1.0) (0.22.1+cu128)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/site-packages (from lightning->radiomana==0.1.0) (6.0.2)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (2025.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/site-packages (from lightning->radiomana==0.1.0) (0.15.1)
# Requirement already satisfied: packaging<27.0,>=20.0 in /usr/local/lib/python3.12/site-packages (from lightning->radiomana==0.1.0) (24.2)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/site-packages (from lightning->radiomana==0.1.0) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.12/site-packages (from lightning->radiomana==0.1.0) (4.14.1)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/site-packages (from lightning->radiomana==0.1.0) (2.5.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (3.12.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning->radiomana==0.1.0) (80.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.61 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (12.8.61)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.57 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (12.8.57)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.57 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (12.8.57)
# Requirement already satisfied: nvidia-cudnn-cu12==9.7.1.26 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (9.7.1.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.3.14 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (12.8.3.14)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.41 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (11.3.3.41)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.55 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (10.3.9.55)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.2.55 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (11.7.2.55)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.7.53 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (12.5.7.53)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.55 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (12.8.55)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.61 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (12.8.61)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.0.11 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (1.13.0.11)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.12/site-packages (from torch->radiomana==0.1.0) (3.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->radiomana==0.1.0) (3.7)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/site-packages (from sympy>=1.13.3->torch->radiomana==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/site-packages (from jinja2->torch->radiomana==0.1.0) (3.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/site-packages (from scikit-learn->radiomana==0.1.0) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/site-packages (from scikit-learn->radiomana==0.1.0) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/site-packages (from scikit-learn->radiomana==0.1.0) (3.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/site-packages (from torchvision->radiomana==0.1.0) (9.5.0)
# env: DSET_FIOT_HIGHWAY2=../aerospace-rf/ebroyles
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 get_ipython().system('pip install git+https://github.com/the-aerospace-corporation/radiomana.git')
#       2 get_ipython().run_line_magic('env', 'DSET_FIOT_HIGHWAY2=../aerospace-rf/ebroyles')
# ----> 3 import radiomana
#
# ModuleNotFoundError: No module named 'radiomana'
