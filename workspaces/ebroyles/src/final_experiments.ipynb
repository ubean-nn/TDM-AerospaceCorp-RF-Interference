# %%
import os
import torch
import torch.nn as nn
from constants import LABELS
from my_dataset import MyDataset as DS
from model_manager import ModelManager as Manager
from model_manager import MyNN

datapath1 = "standard2/"# flip_specto, resize_specto, [mean, mean, std, std, median, median, min, min, max, max, minloc, minloc, maxloc, maxloc, iqr, iqr], norm0to1
datapath2 = "standard3/"# flip_specto, resize_specto, [std, median, median, min, min, max, max, minloc, minloc, maxloc, maxloc, iqr, iqr]                 , norm0to1
datapath3 = "standard4/"# flip_specto, resize_specto, [std, median, median, min, min, max, max, minloc, minloc, maxloc, maxloc, percentile(75), percentile(75), percentile(25), percentile(25)], norm0to1
datapath4 = "standard5/"# flip_specto, resize_specto, [std, median, median, min, min, max, max, minloc, minloc, maxloc, maxloc, percentile(75), percentile(75), percentile(25), percentile(25), percentile(90), percentil(90), percentil(10), percentile(10)], norm0to1
datapaths = [datapath1, datapath2, datapath3, datapath4]


# Model Outputs: for each sample compute the label_prob = [...9], sum(label_prob) == 1, each spot corresponds to the how likly it is to be that class
# Goal: create several models that when these probabilities are summed the largest prob is the actual label more than 80% of the time
# Baseline Model: NN (shallow), 
# Direct Computation Model: mean and std for each label across features in train, for each sample compute zscores for each label across each feature. -> sum the zscores across each feature at each label to get label_scores
# -> ouput the label_prob, convet each label_scores into negetive so larger scores are better, then use softmax, in theory the output should sum to 1.

# Recover NN: X = flatten(zscores), 9 * num_features, Note zscores[0] has the zscores for a sample at label 0, use the label_scores and L to figure out what are the L best labels I want to keep, multiply by 0 all other labels inside of X
# -> output label_prob

# explore different weights to the different models above to create a voting system that sums togethre the label_prob for each.


# Voting NN (maybe): take in predictions for each model and modify the scale factor to be applied to each 


# Base Models
# Direct Computation Model (train_mean, train_std)
# evaluate with train
# 
# at each base model get the logits self(x)



print("done")
# Out:
# done

# %%
for i,datapath in enumerate(datapaths):
    train_datapaths = [os.path.join(datapath, "train.csv")]
    test_datapaths = [os.path.join(datapath, "test.csv")]
    train_loader = DS.get_loader(train_datapaths, shuffle=True, batch_size=64, num_workers=63)
    test_loader = DS.get_loader(test_datapaths, batch_size=64, num_workers=63)
    
    num_classes = len(LABELS)
    num_features = train_loader.dataset.datasets[0].num_features
    model_class = MyNN
    shallow_model_body = nn.Sequential(
        nn.Linear(num_features, 512),
        nn.ReLU(),
        nn.Linear(512, 256),
        nn.ReLU(),
        nn.Linear(256, num_classes))
    loss_fn = nn.CrossEntropyLoss()
    
    model_name = f"final_exp_basemodel1_data{i+1}" #### REMEMBER TO CHANGE THE NAME
    max_epochs = 8
    manager = Manager(model_name, max_epochs, model_class, shallow_model_body, loss_fn)
    manager.train(train_loader)
    manager.test(test_loader)
    manager.confustion_matrix(test_loader, num_classes)
    manager.plot_logger()
    print("done")
# Out:
# ['standard2/train.csv']
# /usr/local/lib/python3.12/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name       | Type             | Params | Mode
# --------------------------------------------------------
# 0 | model_body | Sequential       | 920 K  | train
# 1 | loss_fn    | CrossEntropyLoss | 0      | train
# --------------------------------------------------------
# 920 K     Trainable params
# 0         Non-trainable params
# 920 K     Total params
# 3.682     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# ...

# %%
for i,datapath in enumerate(datapaths):
    train_datapaths = [os.path.join(datapath, "train.csv")]
    test_datapaths = [os.path.join(datapath, "test.csv")]
    train_loader = DS.get_loader(train_datapaths, shuffle=True, batch_size=64, num_workers=63)
    test_loader = DS.get_loader(test_datapaths, batch_size=64, num_workers=63)
    
    num_classes = len(LABELS)
    num_features = train_loader.dataset.datasets[0].num_features
    model_class = MyNN
    shallow_model_body = nn.Sequential(
        nn.Linear(num_features, 700),
        nn.ReLU(),
        nn.Linear(700, 512),
        nn.ReLU(),
        nn.Linear(512, 256),
        nn.ReLU(),
        nn.Linear(256, num_classes))
    loss_fn = nn.CrossEntropyLoss()
    
    model_name = f"final_exp_basemodel1_data{i+1}" #### REMEMBER TO CHANGE THE NAME
    max_epochs = 6
    manager = Manager(model_name, max_epochs, model_class, shallow_model_body, loss_fn)
    manager.train(train_loader)
    manager.test(test_loader)
    manager.confustion_matrix(test_loader, num_classes)
    manager.plot_logger()
    print("done")
# Out:
# /usr/local/lib/python3.12/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name       | Type             | Params | Mode
# --------------------------------------------------------
# 0 | model_body | Sequential       | 1.6 M  | train
# 1 | loss_fn    | CrossEntropyLoss | 0      | train
# --------------------------------------------------------
# 1.6 M     Trainable params
# 0         Non-trainable params
# 1.6 M     Total params
# 6.274     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# ...
