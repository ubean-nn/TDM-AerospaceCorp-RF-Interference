# %%
# !pip install --index-url https://download.pytorch.org/whl/cpu torch torchvision torchaudio
# !pip install pytorch-lightning torchmetrics matplotlib numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import os
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split, WeightedRandomSampler

import pytorch_lightning as pl
from pytorch_lightning import Trainer, Callback
from torchmetrics.classification import MulticlassAccuracy
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

ROOT = "../fiot_highway2-main"        # folder that contains data/ and train.txt/test.txt
TRAIN_TXT = os.path.join(ROOT, "train.txt")
TEST_TXT  = os.path.join(ROOT, "test.txt")

NUM_CLASSES = 9
ORIG_SHAPE = (512, 243)   # (freq, time)

# Optional: downsample freq/time inside dataset to reduce size
DS_FREQ = 1   # 1 = no downsample, 2 = half freq, 4 = quarter freq, etc.
DS_TIME = 1   # 1 = no downsample, 2 = half time, 4 = quarter time, etc.

# Training settings
BATCH_SIZE = 32
VAL_FRAC = 0.1        # fraction of train for validation
SUBSET_FRAC = 0.2     # use 20% of train data for debugging; set to None for full

RANDOM_SEED = 42
pl.seed_everything(RANDOM_SEED, workers=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
# ----> 7 import torch
#       8 import torch.nn as nn
#       9 import torch.nn.functional as F
#
# File /usr/local/lib/python3.12/site-packages/torch/__init__.py:427
#     425     if USE_GLOBAL_DEPS:
#     426         _load_global_deps()
# --> 427     from torch._C import *  # noqa: F403
#     430 class SymInt:
#     431     """
#     432     Like an int (including magic methods), but redirects all operations on the
#     433     wrapped node. This is used in particular to symbolically record operations
#     434     in the symbolic shape workflow.
#     435     """
#
# ...
